# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importing-external-functions" data-toc-modified-id="Importing-external-functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing external functions</a></span></li><li><span><a href="#Geofabrik/OSM" data-toc-modified-id="Geofabrik/OSM-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Geofabrik/OSM</a></span></li><li><span><a href="#Eubucco" data-toc-modified-id="Eubucco-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Eubucco</a></span></li><li><span><a href="#DBSM" data-toc-modified-id="DBSM-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>DBSM</a></span></li><li><span><a href="#Microsoft" data-toc-modified-id="Microsoft-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Microsoft</a></span></li><li><span><a href="#Boundaries-statistics" data-toc-modified-id="Boundaries-statistics-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Boundaries statistics</a></span></li></ul></div>

# %%
"""
The following code is designed to load datasets and merge them with the GISCO layer, which contains NUTS 3 level province codes. Subsequently, the code calculates the area in square meters of the buildings and determines the number of vertices for each building polygon.

Initially, the code loads the necessary datasets, including the geospatial data of the buildings and the GISCO layer containing the province codes at NUTS 3 level.

After loading the data, the code proceeds to merge the datasets with the GISCO layer based on the province codes.

Next, using the geospatial information of the buildings, the code calculates the area in square meters of each building. The area of each building is determined using the geometries of the corresponding polygons representing the buildings.

Finally, the code calculates the number of vertices for each polygon representing a building. This count is performed by considering the geometry of the polygons and the number of coordinates composing them, excluding the starting and ending points of the polygons, which coincide.


"""
# Out:
# '\nThe following code is designed to load datasets and merge them with the GISCO layer, which contains NUTS 3 level province codes. Subsequently, the code calculates the area in square meters of the buildings and determines the number of vertices for each building polygon.\n\nInitially, the code loads the necessary datasets, including the geospatial data of the buildings and the GISCO layer containing the province codes at NUTS 3 level.\n\nAfter loading the data, the code proceeds to merge the datasets with the GISCO layer based on the province codes.\n\nNext, using the geospatial information of the buildings, the code calculates the area in square meters of each building. The area of each building is determined using the geometries of the corresponding polygons representing the buildings.\n\nFinally, the code calculates the number of vertices for each polygon representing a building. This count is performed by considering the geometry of the polygons and the number of coordinates composing them, excluding the starting and ending points of the polygons, which coincide.\n\n\n'

# %% [markdown]
# # Importing external functions

# %%
#importing common functions
# %run 0-[_functions]-0_methods.ipynb
import warnings
import datetime
warnings.filterwarnings("ignore")

# %% [markdown]
# # Geofabrik/OSM
# https://taginfo.geofabrik.de/europe:italy:centro/keys/building#values<BR>
# https://github.com/ai4up/eubucco/blob/main/tutorials/downloading-parsing-osm.ipynb

# %%
for country in ['DK','SE','EL','BE']:
    #country='MT'
    osm=load_osm_data(country)
    osm['country']=country
    osm_enriched=process_buildings_to_lau_parallel(osm)
    print(datetime.datetime.now(),'exporting results')
    osm_enriched.to_file('/mnt/CAS/20240101_foss4g/datasets/in/countries/%s/osm_enriched.gpkg'%(country),driver='GPKG')
    osm_stat=aggregation(osm_enriched)
    osm_stat.to_excel('/mnt/CAS/20240101_foss4g/datasets/out/%s_osm_output.xlsx'%(country),index=False)
    print(osm_enriched.head(2))
    print('----')
    print(osm_stat)
    print(datetime.datetime.now(),'total number of regions computed:',len(osm_stat))
    print('******\n')
    osm=None
    osm_enriched=None
# Out:
# ['osm-latest-free.shp.zip']
# 2024-02-06 16:27:21.294043 importing osm data for DK - osm-latest-free.shp.zip
# 2024-02-06 16:31:40.003453 imported 3660690 rows
# 2024-02-06 16:31:40.004212 ['building']
# 2024-02-06 16:54:37.799194 total number of regions computed: 11
#      osm-id osm-code osm-fclass        osm-name  osm-type  \
# 0   4250592     1500   building  Rigshospitalet  hospital
# 1  14309996     1500   building        Nykredit    office
#
#                                             geometry source    dataset  \
# 0  POLYGON ((12.56488 55.69608, 12.56522 55.69626...    osm  geofabrik
# 1  POLYGON ((12.57508 55.66973, 12.57572 55.67008...    osm  geofabrik
#
#   country      area_sqm num_vertices nuts_id urban_type       nuts_name
# 0      DK  43669.531812           39   DK011          1  Byen København
# 1      DK   9814.474012            4   DK011          1  Byen København
# ----
#       dataset source nuts_id             nuts_name  urban_type country  \
# 0   geofabrik    osm   DK011        Byen København           1      DK
# 1   geofabrik    osm   DK012      Københavns omegn           1      DK
# 2   geofabrik    osm   DK013          Nordsjælland           2      DK
# 3   geofabrik    osm   DK014              Bornholm           3      DK
# 4   geofabrik    osm   DK021           Østsjælland           2      DK
# 5   geofabrik    osm   DK022  Vest- og Sydsjælland           3      DK
# 6   geofabrik    osm   DK031                   Fyn           2      DK
# 7   geofabrik    osm   DK032            Sydjylland           2      DK
# 8   geofabrik    osm   DK041           Vestjylland           3      DK
# 9   geofabrik    osm   DK042            Østjylland           2      DK
# 10  geofabrik    osm   DK050           Nordjylland           3      DK
#
#     nr_buildings      area_sqm  num_vertices
# 0         100916  6.735612e+07        782926
# 1         192926  1.113508e+08       1462620
# 2         332145  1.474425e+08       2330850
# 3          41399  2.256285e+07        311238
# 4         147096  7.918183e+07       1056184
# 5         609098  2.842976e+08       4343325
# 6         365240  2.117661e+08       2642862
# 7         507983  3.786998e+08       3975908
# 8         351186  2.817888e+08       2736014
# 9         527326  3.467402e+08       3941742
# 10        479560  3.515703e+08       3672508
# 2024-02-06 16:54:37.822900 total number of regions computed: 11
# ******
#
# ['osm-latest-free.shp.zip']
# 2024-02-06 16:54:37.836630 importing osm data for SE - osm-latest-free.shp.zip
# 2024-02-06 16:58:37.130762 imported 3095385 rows
# 2024-02-06 16:58:37.131530 ['building']
# 2024-02-06 17:17:58.040424 total number of regions computed: 21
#     osm-id osm-code osm-fclass           osm-name osm-type  \
# 0  3687818     1500   building               None     None
# 1  4008279     1500   building  Falbygdens museum    civic
#
#                                             geometry source    dataset  \
# 0  POLYGON ((12.29141 57.66564, 12.29147 57.66570...    osm  geofabrik
# 1  POLYGON ((13.55255 58.16871, 13.55276 58.16874...    osm  geofabrik
#
#   country      area_sqm num_vertices nuts_id urban_type             nuts_name
# 0      SE  136974.81859          141   SE232          1  Västra Götalands län
# 1      SE   1530.309368            5   SE232          1  Västra Götalands län
# ----
#       dataset source nuts_id             nuts_name  urban_type country  \
# 0   geofabrik    osm   SE110        Stockholms län           1      SE
# 1   geofabrik    osm   SE121           Uppsala län           2      SE
# 2   geofabrik    osm   SE122     Södermanlands län           2      SE
# 3   geofabrik    osm   SE123     Östergötlands län           2      SE
# 4   geofabrik    osm   SE124            Örebro län           2      SE
# 5   geofabrik    osm   SE125      Västmanlands län           2      SE
# 6   geofabrik    osm   SE211        Jönköpings län           2      SE
# 7   geofabrik    osm   SE212        Kronobergs län           3      SE
# 8   geofabrik    osm   SE213            Kalmar län           3      SE
# 9   geofabrik    osm   SE214          Gotlands län           3      SE
# 10  geofabrik    osm   SE221          Blekinge län           2      SE
# 11  geofabrik    osm   SE224             Skåne län           2      SE
# 12  geofabrik    osm   SE231          Hallands län           2      SE
# 13  geofabrik    osm   SE232  Västra Götalands län           1      SE
# 14  geofabrik    osm   SE311         Värmlands län           2      SE
# 15  geofabrik    osm   SE312          Dalarnas län           3      SE
# 16  geofabrik    osm   SE313        Gävleborgs län           2      SE
# 17  geofabrik    osm   SE321   Västernorrlands län           2      SE
# 18  geofabrik    osm   SE322         Jämtlands län           3      SE
# 19  geofabrik    osm   SE331     Västerbottens län           2      SE
# 20  geofabrik    osm   SE332       Norrbottens län           2      SE
#
#     nr_buildings      area_sqm  num_vertices
# 0         434204  3.514819e+08       2319473
# 1         111017  9.781187e+07        574309
# 2          76072  7.219764e+07        383280
# 3         137760  1.146970e+08        740223
# 4         105707  8.902077e+07        541625
# 5          51926  6.258002e+07        282085
# 6          79695  8.514752e+07        434048
# 7          59737  5.035407e+07        340144
# 8          95662  6.873873e+07        503061
# 9          29617  2.063648e+07        152155
# 10         41916  2.882373e+07        224079
# 11        431570  3.022730e+08       2386035
# 12         72079  6.341516e+07        394947
# 13        535537  4.045811e+08       2796120
# 14        144051  9.989330e+07        729744
# 15        133659  1.000981e+08        650220
# 16        101538  8.589040e+07        514059
# 17        128348  8.981749e+07        644936
# 18         61642  5.207847e+07        318373
# 19        110810  1.187316e+08        629222
# 20        108120  1.265541e+08        566473
# 2024-02-06 17:17:58.065883 total number of regions computed: 21
# ******
#
# ['osm-latest-free.shp.zip']
# 2024-02-06 17:17:58.067372 importing osm data for EL - osm-latest-free.shp.zip
# 2024-02-06 17:19:22.888462 imported 1228197 rows
# 2024-02-06 17:19:22.888610 ['building']
# 2024-02-06 17:27:48.132024 total number of regions computed: 52
#      osm-id osm-code osm-fclass         osm-name        osm-type  \
# 0   6121472     1500   building             None  transportation
# 1  26497060     1500   building  AG. Panteleimon            None
#
#                                             geometry source    dataset  \
# 0  POLYGON ((25.17252 35.33682, 25.17253 35.33699...    osm  geofabrik
# 1  POLYGON ((25.17568 35.22431, 25.17582 35.22431...    osm  geofabrik
#
#   country     area_sqm num_vertices nuts_id urban_type nuts_name
# 0      EL  30999.57576           62   EL431          2  Ηράκλειο
# 1      EL    125.67525            4   EL431          2  Ηράκλειο
# ----
#       dataset source nuts_id  \
# 0   geofabrik    osm   EL301
# 1   geofabrik    osm   EL302
# 2   geofabrik    osm   EL303
# 3   geofabrik    osm   EL304
# 4   geofabrik    osm   EL305
# 5   geofabrik    osm   EL306
# 6   geofabrik    osm   EL307
# 7   geofabrik    osm   EL411
# 8   geofabrik    osm   EL412
# 2024-02-06 18:30:49.982497 total number of regions computed: 44
#      osm-id osm-code osm-fclass                   osm-name osm-type  \
# 0   4414121     1500   building                       None     None
# 1  10317312     1500   building  Technicum Noord-Antwerpen   school
#
#                                             geometry source    dataset  \
# 0  POLYGON ((4.45072 51.18915, 4.45072 51.18916, ...    osm  geofabrik
# 1  POLYGON ((4.41164 51.23124, 4.41164 51.23151, ...    osm  geofabrik
#
#   country     area_sqm num_vertices nuts_id urban_type       nuts_name
# 0      BE  11399.86164           38   BE211          1  Arr. Antwerpen
# 1      BE   5732.97058           11   BE211          1  Arr. Antwerpen
# ----
#       dataset source nuts_id  \
# 0   geofabrik    osm   BE100
# 1   geofabrik    osm   BE211
# 2   geofabrik    osm   BE212
# 3   geofabrik    osm   BE213
# 4   geofabrik    osm   BE221
# 5   geofabrik    osm   BE222
# 6   geofabrik    osm   BE223
# 7   geofabrik    osm   BE231
# 8   geofabrik    osm   BE232
# 9   geofabrik    osm   BE233
# 10  geofabrik    osm   BE234
# 11  geofabrik    osm   BE235
# 12  geofabrik    osm   BE236
# 13  geofabrik    osm   BE241
# 14  geofabrik    osm   BE242
# 15  geofabrik    osm   BE251
# 16  geofabrik    osm   BE252
# 17  geofabrik    osm   BE253
# 18  geofabrik    osm   BE254
# 19  geofabrik    osm   BE255
# 20  geofabrik    osm   BE256
# 21  geofabrik    osm   BE257
# 22  geofabrik    osm   BE258
# 23  geofabrik    osm   BE310
# 24  geofabrik    osm   BE321
# 25  geofabrik    osm   BE322
# 26  geofabrik    osm   BE323
# 27  geofabrik    osm   BE324
# 28  geofabrik    osm   BE325
# 29  geofabrik    osm   BE326
# 30  geofabrik    osm   BE327
# 31  geofabrik    osm   BE331
# 32  geofabrik    osm   BE332
# 33  geofabrik    osm   BE334
# 34  geofabrik    osm   BE335
# 35  geofabrik    osm   BE336
# 36  geofabrik    osm   BE341
# 37  geofabrik    osm   BE342
# 38  geofabrik    osm   BE343
# 39  geofabrik    osm   BE344
# 40  geofabrik    osm   BE345
# 41  geofabrik    osm   BE351
# 42  geofabrik    osm   BE352
# 43  geofabrik    osm   BE353
#
#                                             nuts_name  urban_type country  \
# 0   Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...           1      BE
# 1                                      Arr. Antwerpen           1      BE
# 2                                       Arr. Mechelen           1      BE
# 3                                       Arr. Turnhout           2      BE
# 4                                        Arr. Hasselt           1      BE
# 5                                        Arr. Maaseik           2      BE
# 6                                       Arr. Tongeren           2      BE
# 7                                          Arr. Aalst           1      BE
# 8                                    Arr. Dendermonde           1      BE
# 9                                          Arr. Eeklo           2      BE
# 10                                          Arr. Gent           2      BE
# 11                                    Arr. Oudenaarde           2      BE
# 12                                  Arr. Sint-Niklaas           1      BE
# 13                               Arr. Halle-Vilvoorde           1      BE
# 14                                        Arr. Leuven           2      BE
# 15                                        Arr. Brugge           2      BE
# 16                                     Arr. Diksmuide           2      BE
# 17                                         Arr. Ieper           2      BE
# 18                                      Arr. Kortrijk           1      BE
# 19                                      Arr. Oostende           2      BE
# 20                                     Arr. Roeselare           2      BE
# 21                                         Arr. Tielt           2      BE
# 22                                        Arr. Veurne           2      BE
# 23                                      Arr. Nivelles           2      BE
# 24                                           Arr. Ath           3      BE
# 25                                     Arr. Charleroi           1      BE
# 26                                          Arr. Mons           1      BE
# 27                                      Arr. Mouscron           1      BE
# 28                                      Arr. Soignies           2      BE
# 29                                         Arr. Thuin           2      BE
# 30                                       Arr. Tournai           3      BE
# 31                                           Arr. Huy           3      BE
# 32                                         Arr. Liège           1      BE
# 33                                       Arr. Waremme           3      BE
# 34              Arr. Verviers - communes francophones           2      BE
# 35    Bezirk Verviers - Deutschsprachige Gemeinschaft           3      BE
# 36                                         Arr. Arlon           3      BE
# 37                                      Arr. Bastogne           3      BE
# 38                             Arr. Marche-en-Famenne           3      BE
# 39                                   Arr. Neufchâteau           3      BE
# 40                                        Arr. Virton           3      BE
# 41                                        Arr. Dinant           3      BE
# 42                                         Arr. Namur           2      BE
# 43                                 Arr. Philippeville           3      BE
#
#     nr_buildings      area_sqm  num_vertices
# 0         248865  9.113840e+07       1877798
# 1         460924  1.917299e+08       3036828
# 2         209454  8.867939e+07       1324614
# 3         389794  1.626152e+08       2637007
# 4         292333  1.178323e+08       2108862
# 5         188561  7.908970e+07       1312139
# 6         158397  5.740972e+07       1174888
# 7         189376  5.717051e+07       1349397
# 8         152155  5.190075e+07       1112242
# 9          26177  1.244714e+07        178094
# 10        333562  1.319754e+08       2375140
# 11         51920  2.292563e+07        368930
# 12        201921  7.861052e+07       1426632
# 13        295956  1.104663e+08       1947260
# 14        268199  1.040753e+08       1766845
# 15        204577  7.416247e+07       1513311
# 16         55153  2.507965e+07        404202
# 17         94729  4.230198e+07        668884
# 18        166280  7.507508e+07       1170056
# 19        102861  3.334685e+07        747897
# 20        113749  5.354070e+07        780472
# 21         63447  3.796230e+07        468346
# 22         51544  1.897477e+07        412131
# 23        230113  6.873855e+07       1442604
# 24         57062  2.105181e+07        375358
# 25        167498  5.705571e+07        977196
# 26         98759  4.237026e+07        656450
# 27         48886  1.762880e+07        301895
# 28        108105  3.523023e+07        734932
# 29         97390  2.914679e+07        608670
# 30         63085  2.843843e+07        449097
# 31         68896  2.378249e+07        378818
# 32        299016  9.678917e+07       1745465
# 33         51163  1.756758e+07        291617
# 34        118946  4.312873e+07        662981
# 35         48214  2.241014e+07        283475
# 36         35530  1.257955e+07        211093
# 37         36850  1.599169e+07        201067
# 38         40459  1.587908e+07        217492
# 39         52873  1.889871e+07        299677
# 40         29604  1.246308e+07        175603
# 41         68657  2.712234e+07        402323
# 42        135543  5.561179e+07        813443
# 43         34868  1.420115e+07        201893
# 2024-02-06 18:30:51.516297 total number of regions computed: 44
# ******

# %% [markdown]
# # Eubucco

# %%
for country in ['DK','SE','EL','BE']:
    #country='MT'
    eubucco=load_eubucco_data(country)
    eubucco['country']=country
    eubucco_enriched=process_buildings_to_lau_parallel(eubucco)
    print(datetime.datetime.now(),'exporting results')
    eubucco_enriched.to_file('/mnt/CAS/20240101_foss4g/datasets/in/countries/%s/eubucco_enriched.gpkg'%(country),driver='GPKG')
    eubucco_stat=aggregation(eubucco_enriched)
    eubucco_stat.to_excel('/mnt/CAS/20240101_foss4g/datasets/out/%s_eubucco_output.xlsx'%(country),index=False)
    print(eubucco_enriched.head(2))
    print('----')
    print(eubucco_stat.head(2))
    print(datetime.datetime.now(),'total number of regions computed:',len(eubucco_stat))
    print('******\n')
    eubucco=None
    eubucco_enriched=None
# Out:
# 2024-02-06 18:30:51.524369 importing Eubucco data for DK
# 2024-02-06 18:43:27.981934 imported 5691756 rows
# 2024-02-06 21:41:27.471037 total number of regions computed: 44
#                  id height   age  type                id_source type_source  \
# 0  v0.1-DNK.1.1_1-0   None  None  None  dk.bu-core2d.1005280530        None
# 1  v0.1-DNK.1.1_1-1   None  None  None  dk.bu-core2d.1104978398        None
#
#                                             geometry   source  dataset  \
# 0  POLYGON ((12.33130 55.65694, 12.33124 55.65691...  eubucco  eubucco
# 1  POLYGON ((12.34381 55.66785, 12.34377 55.66773...  eubucco  eubucco
#
#   country        eubucco-id     area_sqm num_vertices nuts_id urban_type  \
# 0      DK  v0.1-DNK.1.1_1-0  2712.656064            8   DK012          1
# 1      DK  v0.1-DNK.1.1_1-1  1022.052761           10   DK012          1
#
#           nuts_name
# 0  Københavns omegn
# 1  Københavns omegn
# ----
#      dataset source nuts_id  \
# 0  geofabrik    osm   BE100
# 1  geofabrik    osm   BE211
#
#                                            nuts_name  urban_type country  \
# 0  Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...           1      BE
# 1                                     Arr. Antwerpen           1      BE
#
#    nr_buildings      area_sqm  num_vertices
# 0        248865  9.113840e+07       1877798
# 1        460924  1.917299e+08       3036828
# 2024-02-06 21:41:39.696610 total number of regions computed: 44
# ******
#
# 2024-02-06 21:41:39.697214 importing Eubucco data for SE
# 2024-02-06 22:00:25.316512 imported 2532313 rows
# 2024-02-07 03:51:01.061221 total number of regions computed: 44
#                  id height  age             type            id_source  \
# 0  v0.1-SWE.1.1_1-0    NaN  NaN  non-residential   sweden-latest24159
# 1  v0.1-SWE.1.1_1-1    NaN  NaN             None  sweden-latest168092
#
#   type_source                                           geometry   source  \
# 0  industrial  POLYGON ((14.74339 56.18579, 14.74352 56.18627...  eubucco
# 1        None  POLYGON ((14.86523 56.17129, 14.86549 56.17134...  eubucco
#
#    dataset country        eubucco-id      area_sqm num_vertices nuts_id  \
# 0  eubucco      SE  v0.1-SWE.1.1_1-0  72365.920043          248   SE221
# 1  eubucco      SE  v0.1-SWE.1.1_1-1    763.642956           86   SE221
#
#   urban_type     nuts_name
# 0          2  Blekinge län
# 1          2  Blekinge län
# ----
#      dataset source nuts_id  \
# 0  geofabrik    osm   BE100
# 1  geofabrik    osm   BE211
#
#                                            nuts_name  urban_type country  \
# 0  Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...           1      BE
# 1                                     Arr. Antwerpen           1      BE
#
#    nr_buildings      area_sqm  num_vertices
# 0        248865  9.113840e+07       1877798
# 1        460924  1.917299e+08       3036828
# 2024-02-07 03:51:06.094034 total number of regions computed: 44
# ******
#
# 2024-02-07 03:51:06.094177 importing Eubucco data for EL
# 2024-02-07 04:09:11.022705 imported 864237 rows
# 2024-02-07 04:35:10.107145 total number of regions computed: 44
#                    id height  age  type            id_source type_source  \
# 0  v0.1-GRC.1.1.1_1-0    NaN  NaN  None  greece-latest258038        None
# 1  v0.1-GRC.1.1.1_1-1    NaN  NaN  None  greece-latest258039        None
#
#                                             geometry   source  dataset  \
# 0  POLYGON ((24.98543 39.53588, 24.98548 39.53596...  eubucco  eubucco
# 1  POLYGON ((24.98808 39.53739, 24.98819 39.53740...  eubucco  eubucco
#
#   country          eubucco-id    area_sqm num_vertices nuts_id urban_type  \
# 0      EL  v0.1-GRC.1.1.1_1-0  319.220251           68   EL411          3
# 1      EL  v0.1-GRC.1.1.1_1-1  188.644985           68   EL411          3
#
#         nuts_name
# 0  Λέσβος, Λήμνος
# 1  Λέσβος, Λήμνος
# ----
#      dataset source nuts_id  \
# 0  geofabrik    osm   BE100
# 1  geofabrik    osm   BE211
#
#                                            nuts_name  urban_type country  \
# 0  Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...           1      BE
# 1                                     Arr. Antwerpen           1      BE
#
#    nr_buildings      area_sqm  num_vertices
# 0        248865  9.113840e+07       1877798
# 1        460924  1.917299e+08       3036828
# 2024-02-07 04:35:14.091827 total number of regions computed: 44
# ******
#
# 2024-02-07 04:35:14.092598 importing Eubucco data for BE
# 2024-02-07 06:34:19.375324 imported 8634500 rows
# 2024-02-07 09:22:48.400956 total number of regions computed: 44
#                      id height   age  type    id_source type_source  \
# 0  v0.1-BEL.1.1.1.1_1-0   3.04  None  None  GML_9003447        None
# 1  v0.1-BEL.1.1.1.1_1-1   2.41  None  None  GML_9003453        None
#
#                                             geometry   source  dataset  \
# 0  POLYGON ((4.25406 50.82181, 4.25409 50.82183, ...  eubucco  eubucco
# 1  POLYGON ((4.24662 50.81974, 4.24664 50.81971, ...  eubucco  eubucco
#
#   country            eubucco-id   area_sqm num_vertices nuts_id urban_type  \
# 0      BE  v0.1-BEL.1.1.1.1_1-0  28.658427            8   BE100          1
# 1      BE  v0.1-BEL.1.1.1.1_1-1  45.429448            4   BE100          1
#
#                                            nuts_name
# 0  Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...
# 1  Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...
# ----
#      dataset source nuts_id  \
# 0  geofabrik    osm   BE100
# 1  geofabrik    osm   BE211
#
#                                            nuts_name  urban_type country  \
# 0  Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...           1      BE
# 1                                     Arr. Antwerpen           1      BE
#
#    nr_buildings      area_sqm  num_vertices
# 0        248865  9.113840e+07       1877798
# 1        460924  1.917299e+08       3036828
# 2024-02-07 09:22:51.183322 total number of regions computed: 44
# ******

# %%
#only aggregation
for country in ['DK','SE','EL','BE']:
    dataset='eubucco'
    print('processing',country)
    eubucco_enriched=load_enriched_data(country,dataset)
    eubucco_stat=aggregation(eubucco_enriched)
    eubucco_stat.to_excel('/mnt/CAS/20240101_foss4g/datasets/out/%s_eubucco_output.xlsx'%(country),index=False)
    print(eubucco_enriched.head(2))
    print('----')
    print(eubucco_stat.head(2))
    print(datetime.datetime.now(),'total number of regions computed:',len(eubucco_stat))
    print('******\n')
    eubucco=None
    eubucco_enriched=None

# %% [markdown]
# # DBSM
# Here we may have different sources for the same NUTS, take care to aggregate after

# %%
for country,country_extended in zip(['DK','SE','EL','BE'],['denmark','sweden','greece','belgium']):
    dbsm=load_dbsm_data(country,country_extended)
    dbsm['country']=country
    dbsm_enriched=process_buildings_to_lau_parallel(dbsm)
    print(datetime.datetime.now(),'exporting results')
    dbsm_enriched.to_file('/mnt/CAS/20240101_foss4g/datasets/in/countries/%s/jrc-dbsm_enriched.gpkg'%(country),driver='GPKG')
    
    dbsm_stat=aggregation(dbsm_enriched)
    dbsm_stat.to_excel('/mnt/CAS/20240101_foss4g/datasets/out/%s_jrc-dbsm_output.xlsx'%(country),index=False)
    print(dbsm_enriched.head(2))
    print('----')
    print(dbsm_stat.head(2))
    print(datetime.datetime.now(),'total number of regions computed:',len(dbsm_stat))
    print('******\n')
    dbsm=None
    dbsm_enriched=None
# Out:
# 2024-02-07 09:22:54.785395 importing JRC-dbsm data for DK : denmark
# 2024-02-07 09:27:24.103625 imported 3770334 rows
# 2024-02-07 10:04:43.321481 total number of regions computed: 33
#   source                                           geometry dataset country  \
# 0    osm  POLYGON ((8.79647 54.97307, 8.79656 54.97293, ...     jrc      DK
# 1    osm  POLYGON ((8.76750 54.97691, 8.76769 54.97693, ...     jrc      DK
#
#   jrc-id     area_sqm num_vertices nuts_id urban_type   nuts_name
# 0      0  1392.354379           10   DK032          2  Sydjylland
# 1      1  1173.425553           10   DK032          2  Sydjylland
# ----
#   dataset source nuts_id         nuts_name  urban_type country  nr_buildings  \
# 0     jrc    esm   DK011    Byen København           1      DK           521
# 1     jrc    esm   DK012  Københavns omegn           1      DK           508
#
#        area_sqm  num_vertices
# 0  2.308576e+06         25735
# 1  1.136397e+06         17467
# 2024-02-07 10:04:43.503473 total number of regions computed: 33
# ******
#
# 2024-02-07 10:04:43.503894 importing JRC-dbsm data for SE : sweden
# 2024-02-07 10:10:37.946805 imported 4978298 rows
# 2024-02-07 10:46:07.140437 total number of regions computed: 63
#   source                                           geometry dataset country  \
# 0    osm  POLYGON ((13.32168 55.83857, 13.32199 55.83810...     jrc      SE
# 1    osm  POLYGON ((13.32214 55.83743, 13.32238 55.83748...     jrc      SE
#
#   jrc-id     area_sqm num_vertices nuts_id urban_type  nuts_name
# 0      0  7755.768408            6   SE224          2  Skåne län
# 1      1  6009.779833            8   SE224          2  Skåne län
# ----
#   dataset source nuts_id       nuts_name  urban_type country  nr_buildings  \
# 0     jrc    esm   SE110  Stockholms län           1      SE          1905
# 1     jrc    esm   SE121     Uppsala län           2      SE          2326
#
#        area_sqm  num_vertices
# 0  1.224737e+07         90125
# 1  9.218359e+06         82338
# 2024-02-07 10:46:07.180264 total number of regions computed: 63
# ******
#
# 2024-02-07 10:46:07.180377 importing JRC-dbsm data for EL : greece
# 2024-02-07 10:51:21.426447 imported 4562789 rows
# 2024-02-07 11:22:04.663753 total number of regions computed: 156
#   source                                           geometry dataset country  \
# 0    osm  POLYGON ((24.11522 34.81053, 24.11526 34.81050...     jrc      EL
# 1    osm  POLYGON ((24.11500 34.81069, 24.11490 34.81057...     jrc      EL
#
#   jrc-id    area_sqm num_vertices nuts_id urban_type nuts_name
# 0      0   48.169087            4   EL434          2     Χανιά
# 1      1  142.532409            4   EL434          2     Χανιά
# ----
#   dataset source nuts_id              nuts_name  urban_type country  \
# 0     jrc    esm   EL301  Βόρειος Τομέας Αθηνών           1      EL
# 1     jrc    esm   EL302  Δυτικός Τομέας Αθηνών           1      EL
#
#    nr_buildings       area_sqm  num_vertices
# 0           613  471352.500181         20348
# 1           317  466530.318067         13097
# 2024-02-07 11:22:04.800575 total number of regions computed: 156
# ******
#
# 2024-02-07 11:22:04.801030 importing JRC-dbsm data for BE : belgium
# 2024-02-07 11:31:50.087001 imported 6608720 rows
# 2024-02-07 12:13:21.426170 total number of regions computed: 132
#   source                                           geometry dataset country  \
# 0    osm  POLYGON ((4.68429 49.99676, 4.68460 49.99679, ...     jrc      BE
# 1    osm  POLYGON ((4.68400 49.99672, 4.68375 49.99669, ...     jrc      BE
#
#   jrc-id    area_sqm num_vertices nuts_id urban_type           nuts_name
# 0      0  498.408001            4   BE353          3  Arr. Philippeville
# 1      1   188.54242            5   BE353          3  Arr. Philippeville
# ----
#   dataset source nuts_id                                          nuts_name  \
# 0     jrc    esm   BE100  Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...
# 1     jrc    esm   BE211                                     Arr. Antwerpen
#
#    urban_type country  nr_buildings      area_sqm  num_vertices
# 0           1      BE           378  6.722481e+05         14632
# 1           1      BE          3537  8.888024e+06        155435
# 2024-02-07 12:13:21.886334 total number of regions computed: 132
# ******

# %% [markdown]
# # Microsoft

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape
import datetime
import warnings
import datetime
warnings.filterwarnings("ignore")

# this is the name of the geography you want to retrieve. update to meet your needs
def get_data(location,country):
    dataset_links = pd.read_csv("https://minedbuildings.blob.core.windows.net/global-buildings/dataset-links.csv")
    greece_links = dataset_links[dataset_links.Location == location]
    gdf=[]
    i=1
    microsoft_buildings_stats=[]
    for _, row in greece_links.iterrows():
        print(datetime.datetime.now(),country,'importing link nr:',i)
        df = pd.read_json(row.Url, lines=True)
        df['geometry'] = df['geometry'].apply(shape)
        df['country']=country
        df['dataset']='microsoft'
        df['source']='microsoft'
        tmp=gpd.GeoDataFrame(df, crs=4326)
        print(datetime.datetime.now(),country,'processing link nr:',i,'\n')
        i+=1
        gdf.append(tmp)

    #saving original data
    print(datetime.datetime.now(),'merging geometries')
    gdf=pd.concat(gdf)
    print(datetime.datetime.now(),'mapping geometries to nuts')
    gdf_enriched=process_buildings_to_lau_parallel(gdf)
    print(datetime.datetime.now(),'exporting geometries')
    gdf_enriched.to_file('/mnt/CAS/20240101_foss4g/datasets/in/countries/%s/microsoft_enriched.gpkg'%(country),driver='GPKG')
    return gdf_enriched

for location,country in zip(['Denmark','Greece','Belgium'],['DK','EL','BE']):
    microsoft_enriched=get_data(location,country)
    print(datetime.datetime.now(),'computing aggregation by NUTS')
    microsoft_enriched_stat=aggregation(microsoft_enriched)
    microsoft_enriched_stat.to_excel('/mnt/CAS/20240101_foss4g/datasets/out/%s_microsoft_output.xlsx'%(country),index=False)
    print(microsoft_enriched.head(2))
    print('----')
    print(microsoft_enriched_stat.head(2))
    print(datetime.datetime.now(),'total number of regions computed:',len(microsoft_enriched_stat))
    print('******')
# Out:
# 2024-02-07 18:57:47.793739 DK importing link nr: 1
# 2024-02-07 18:57:51.663130 DK processing link nr: 1
#
# 2024-02-07 18:57:51.663390 DK importing link nr: 2
# 2024-02-07 18:57:53.551007 DK processing link nr: 2
#
# 2024-02-07 18:57:53.551579 DK importing link nr: 3
# 2024-02-07 18:57:56.536998 DK processing link nr: 3
#
# 2024-02-07 18:57:56.537677 DK importing link nr: 4
# 2024-02-07 18:58:14.566115 DK processing link nr: 4
#
# 2024-02-07 18:58:14.566430 DK importing link nr: 5
# 2024-02-07 18:58:15.991211 DK processing link nr: 5
#
# 2024-02-07 18:58:15.991444 DK importing link nr: 6
# 2024-02-07 18:58:17.920598 DK processing link nr: 6
#
# 2024-02-07 18:58:17.921551 DK importing link nr: 7
# 2024-02-07 18:58:23.019314 DK processing link nr: 7
#
# 2024-02-07 18:58:23.020312 DK importing link nr: 8
# 2024-02-07 18:58:30.067240 DK processing link nr: 8
#
# 2024-02-07 18:58:30.068017 DK importing link nr: 9
# 2024-02-07 18:58:39.742793 DK processing link nr: 9
#
# 2024-02-07 18:58:39.743063 DK importing link nr: 10
# 2024-02-07 18:58:46.762110 DK processing link nr: 10
#
# 2024-02-07 18:58:46.762922 DK importing link nr: 11
# 2024-02-07 18:59:00.940915 DK processing link nr: 11
#
# 2024-02-07 18:59:00.941706 DK importing link nr: 12
# 2024-02-07 18:59:15.268865 DK processing link nr: 12
#
# 2024-02-07 18:59:15.269169 DK importing link nr: 13
# 2024-02-07 18:59:30.618705 DK processing link nr: 13
#
# 2024-02-07 18:59:30.619455 DK importing link nr: 14
# 2024-02-07 18:59:55.714467 DK processing link nr: 14
#
# 2024-02-07 18:59:55.714788 DK importing link nr: 15
# 2024-02-07 18:59:57.186639 DK processing link nr: 15
#
# 2024-02-07 18:59:57.186866 DK importing link nr: 16
# 2024-02-07 19:00:08.158589 DK processing link nr: 16
#
# 2024-02-07 19:00:08.159351 DK importing link nr: 17
# 2024-02-07 19:00:26.054943 DK processing link nr: 17
#
# 2024-02-07 19:00:26.055264 DK importing link nr: 18
# 2024-02-07 19:00:47.864554 DK processing link nr: 18
#
# 2024-02-07 19:00:47.865336 DK importing link nr: 19
# 2024-02-07 19:01:05.427219 DK processing link nr: 19
#
# 2024-02-07 19:01:05.427516 DK importing link nr: 20
# 2024-02-07 19:01:29.167339 DK processing link nr: 20
#
# 2024-02-07 19:01:29.167641 DK importing link nr: 21
# 2024-02-07 19:02:03.728748 DK processing link nr: 21
#
# 2024-02-07 19:10:13.794000 DK processing link nr: 47
#
# 2024-02-07 19:10:13.794867 DK importing link nr: 48
# 2024-02-07 19:10:15.109139 DK processing link nr: 48
#
# 2024-02-07 19:10:15.109814 DK importing link nr: 49
# 2024-02-07 19:10:16.364157 DK processing link nr: 49
#
# 2024-02-07 19:10:16.364410 DK importing link nr: 50
# 2024-02-07 19:10:18.004141 DK processing link nr: 50
#
# 2024-02-07 19:10:18.004754 DK importing link nr: 51
# 2024-02-07 19:10:19.234224 DK processing link nr: 51
#
# 2024-02-07 19:10:19.234829 merging geometries
# 2024-02-07 19:10:20.085162 mapping geometries to nuts
# 2024-02-07 19:18:26.541868 exporting geometries
# 2024-02-07 19:40:51.986310 computing aggregation by NUTS
# 2024-02-07 19:40:53.621428 total number of regions computed: 11
#       type                            properties  \
# 0  Feature  {'height': -1.0, 'confidence': -1.0}
# 1  Feature  {'height': -1.0, 'confidence': -1.0}
#
#                                             geometry country    dataset  \
# 0  POLYGON ((9.67933 57.32800, 9.67941 57.32800, ...      DK  microsoft
# 1  POLYGON ((9.68423 57.34584, 9.68443 57.34581, ...      DK  microsoft
#
#       source area_sqm num_vertices nuts_id urban_type    nuts_name
# 0  microsoft      117            4   DK050          3  Nordjylland
# 1  microsoft      403            4   DK050          3  Nordjylland
# ----
#      dataset     source nuts_id         nuts_name  urban_type country  \
# 0  microsoft  microsoft   DK011    Byen København           1      DK
# 1  microsoft  microsoft   DK012  Københavns omegn           1      DK
#
#    nr_buildings   area_sqm  num_vertices
# 0         99032   71209710        575849
# 1        205856  111971211       1194695
# 2024-02-07 19:40:53.715007 total number of regions computed: 11
# ******
# 2024-02-07 19:41:00.223853 EL importing link nr: 1
# 2024-02-07 19:41:04.037764 EL processing link nr: 1
#
# 2024-02-07 19:41:04.038001 EL importing link nr: 2
# 2024-02-07 19:41:14.242733 EL processing link nr: 2
#
# 2024-02-07 19:41:14.243028 EL importing link nr: 3
# 2024-02-07 19:41:33.655019 EL processing link nr: 3
#
# 2024-02-07 19:41:33.655824 EL importing link nr: 4
# 2024-02-07 19:41:34.890707 EL processing link nr: 4
#
# 2024-02-07 19:41:34.891528 EL importing link nr: 5
# 2024-02-07 19:41:49.601780 EL processing link nr: 5
#
# 2024-02-07 19:41:49.602554 EL importing link nr: 6
# 2024-02-07 19:42:05.247236 EL processing link nr: 6
#
# 2024-02-07 19:42:05.247547 EL importing link nr: 7
# 2024-02-07 19:42:11.083616 EL processing link nr: 7
#
# 2024-02-07 19:42:11.084269 EL importing link nr: 8
# 2024-02-07 19:42:24.144391 EL processing link nr: 8
#
# 2024-02-07 19:42:24.144664 EL importing link nr: 9
# 2024-02-07 19:42:33.342253 EL processing link nr: 9
#
# 2024-02-07 19:42:33.342540 EL importing link nr: 10
# 2024-02-07 19:42:35.968261 EL processing link nr: 10
#
# 2024-02-07 19:42:35.969220 EL importing link nr: 11
# 2024-02-07 19:42:38.161690 EL processing link nr: 11
#
# 2024-02-07 19:58:34.250973 EL processing link nr: 87
#
# 2024-02-07 19:58:34.251602 EL importing link nr: 88
# 2024-02-07 19:58:39.933231 EL processing link nr: 88
#
# 2024-02-07 19:58:39.933527 EL importing link nr: 89
# 2024-02-07 19:58:41.164249 EL processing link nr: 89
#
# 2024-02-07 19:58:41.165092 EL importing link nr: 90
# 2024-02-07 19:58:51.792216 EL processing link nr: 90
#
# 2024-02-07 19:58:51.792510 EL importing link nr: 91
# 2024-02-07 19:58:56.421939 EL processing link nr: 91
#
# 2024-02-07 19:58:56.422742 EL importing link nr: 92
# 2024-02-07 19:59:10.121673 EL processing link nr: 92
#
# 2024-02-07 19:59:10.122444 EL importing link nr: 93
# 2024-02-07 19:59:41.126772 EL processing link nr: 93
#
# 2024-02-07 19:59:41.127084 EL importing link nr: 94
# 2024-02-07 19:59:42.590147 EL processing link nr: 94
#
# 2024-02-07 19:59:42.590429 EL importing link nr: 95
# 2024-02-07 19:59:47.537900 EL processing link nr: 95
#
# 2024-02-07 19:59:47.538733 EL importing link nr: 96
# 2024-02-07 19:59:49.529912 EL processing link nr: 96
#
# 2024-02-07 19:59:49.530755 EL importing link nr: 97
# 2024-02-07 19:59:51.373403 EL processing link nr: 97
#
# 2024-02-07 19:59:51.374085 EL importing link nr: 98
# 2024-02-07 19:59:58.536665 EL processing link nr: 98
#
# 2024-02-07 19:59:58.537664 EL importing link nr: 99
# 2024-02-07 20:00:01.748263 EL processing link nr: 99
#
# 2024-02-07 20:00:01.749058 EL importing link nr: 100
# 2024-02-07 20:00:04.138342 EL processing link nr: 100
#
# 2024-02-07 20:00:04.138549 EL importing link nr: 101
# 2024-02-07 20:00:21.660143 EL processing link nr: 101
#
# 2024-02-07 20:00:21.661034 EL importing link nr: 102
# 2024-02-07 20:00:26.385623 EL processing link nr: 102
#
# 2024-02-07 20:00:26.386532 EL importing link nr: 103
# 2024-02-07 20:00:27.654485 EL processing link nr: 103
#
# 2024-02-07 20:00:27.654733 EL importing link nr: 104
# 2024-02-07 20:00:29.866544 EL processing link nr: 104
#
# 2024-02-07 20:00:29.866786 EL importing link nr: 105
# 2024-02-07 20:00:37.601638 EL processing link nr: 105
#
# 2024-02-07 20:00:37.602315 EL importing link nr: 106
# 2024-02-07 20:00:39.176126 EL processing link nr: 106
#
# 2024-02-07 20:00:39.176332 merging geometries
# 2024-02-07 20:00:40.596509 mapping geometries to nuts
# 2024-02-07 20:13:47.407233 exporting geometries
# 2024-02-07 20:51:30.596540 computing aggregation by NUTS
# 2024-02-07 20:51:33.285973 total number of regions computed: 52
#       type                            properties  \
# 0  Feature  {'height': -1.0, 'confidence': -1.0}
# 1  Feature  {'height': -1.0, 'confidence': -1.0}
#
#                                             geometry country    dataset  \
# 0  POLYGON ((22.00155 41.02388, 22.00142 41.02388...      EL  microsoft
# 1  POLYGON ((22.00692 41.02440, 22.00698 41.02435...      EL  microsoft
#
#       source area_sqm num_vertices nuts_id urban_type nuts_name
# 0  microsoft      182            4   EL524          3     Πέλλα
# 1  microsoft      306            6   EL524          3     Πέλλα
# ----
#      dataset     source nuts_id              nuts_name  urban_type country  \
# 0  microsoft  microsoft   EL301  Βόρειος Τομέας Αθηνών           1      EL
# 1  microsoft  microsoft   EL302  Δυτικός Τομέας Αθηνών           1      EL
#
#    nr_buildings  area_sqm  num_vertices
# 0         75239  40474118        471718
# 1         38780  28802680        314760
# 2024-02-07 20:51:33.314889 total number of regions computed: 52
# ******
# 2024-02-07 20:51:40.148800 BE importing link nr: 1
# 2024-02-07 20:51:41.567331 BE processing link nr: 1
#
# 2024-02-07 20:51:41.568129 BE importing link nr: 2
# 2024-02-07 20:51:57.675253 BE processing link nr: 2
#
# 2024-02-07 20:51:57.675994 BE importing link nr: 3
# 2024-02-07 20:52:27.281198 BE processing link nr: 3
#
# 2024-02-07 20:52:27.281538 BE importing link nr: 4
# 2024-02-07 20:52:44.669881 BE processing link nr: 4
#
# 2024-02-07 20:52:44.670199 BE importing link nr: 5
# 2024-02-07 20:54:18.900958 BE processing link nr: 5
#
# 2024-02-07 20:54:18.901836 BE importing link nr: 6
# 2024-02-07 20:56:19.560291 BE processing link nr: 6
#
# 2024-02-07 20:56:19.561181 BE importing link nr: 7
# 2024-02-07 20:57:16.117694 BE processing link nr: 7
#
# 2024-02-07 20:57:16.118765 BE importing link nr: 8
# 2024-02-07 20:57:44.277249 BE processing link nr: 8
#
# 2024-02-07 20:57:44.277555 BE importing link nr: 9
# 2024-02-07 20:59:57.268166 BE processing link nr: 9
#
# 2024-02-07 20:59:57.268609 BE importing link nr: 10
# 2024-02-07 21:01:28.051485 BE processing link nr: 10
#
# 2024-02-07 21:01:28.051811 BE importing link nr: 11
# 2024-02-07 21:01:29.384507 BE processing link nr: 11
#
# 2024-02-07 21:01:29.385439 BE importing link nr: 12
# 2024-02-07 21:01:44.096843 BE processing link nr: 12
#
# 2024-02-07 21:01:44.097800 BE importing link nr: 13
# 2024-02-07 21:02:40.804523 BE processing link nr: 13
#
# 2024-02-07 21:02:40.804818 BE importing link nr: 14
# 2024-02-07 21:02:43.975777 BE processing link nr: 14
#
# 2024-02-07 21:02:43.976686 BE importing link nr: 15
# 2024-02-07 21:04:02.251556 BE processing link nr: 15
#
# 2024-02-07 21:04:02.251985 BE importing link nr: 16
# 2024-02-07 21:04:57.545033 BE processing link nr: 16
#
# 2024-02-07 21:04:57.545346 BE importing link nr: 17
# 2024-02-07 21:05:14.316577 BE processing link nr: 17
#
# 2024-02-07 21:05:14.317320 BE importing link nr: 18
# 2024-02-07 21:05:35.583511 BE processing link nr: 18
#
# 2024-02-07 21:05:35.583809 BE importing link nr: 19
# 2024-02-07 21:05:37.241605 BE processing link nr: 19
#
# 2024-02-07 21:05:37.242580 BE importing link nr: 20
# 2024-02-07 21:05:46.502675 BE processing link nr: 20
#
# 2024-02-07 21:05:46.503544 BE importing link nr: 21
# 2024-02-07 21:05:47.944056 BE processing link nr: 21
#
# 2024-02-07 21:05:47.944643 BE importing link nr: 22
# 2024-02-07 21:06:05.313985 BE processing link nr: 22
#
# 2024-02-07 21:06:05.314953 BE importing link nr: 23
# 2024-02-07 21:06:45.227014 BE processing link nr: 23
#
# 2024-02-07 21:06:45.227768 BE importing link nr: 24
# 2024-02-07 21:06:47.209330 BE processing link nr: 24
#
# 2024-02-07 21:06:47.210226 BE importing link nr: 25
# 2024-02-07 21:06:56.536423 BE processing link nr: 25
#
# 2024-02-07 21:06:56.536679 BE importing link nr: 26
# 2024-02-07 21:07:05.833509 BE processing link nr: 26
#
# 2024-02-07 21:07:05.833734 merging geometries
# 2024-02-07 21:07:06.859888 mapping geometries to nuts
# 2024-02-07 21:18:08.385863 exporting geometries
# 2024-02-07 21:47:59.577114 computing aggregation by NUTS
# 2024-02-07 21:48:01.828536 total number of regions computed: 44
#       type                                         properties  \
# 0  Feature  {'height': -1.0, 'confidence': 0.9578999876976...
# 1  Feature  {'height': -1.0, 'confidence': 0.9463000297546...
#
#                                             geometry country    dataset  \
# 0  POLYGON ((2.80775 51.18394, 2.80780 51.18403, ...      BE  microsoft
# 1  POLYGON ((2.80962 51.18231, 2.80965 51.18215, ...      BE  microsoft
#
#       source area_sqm num_vertices nuts_id urban_type      nuts_name
# 0  microsoft      294            8   BE255          2  Arr. Oostende
# 1  microsoft      629            6   BE255          2  Arr. Oostende
# ----
#      dataset     source nuts_id  \
# 0  microsoft  microsoft   BE100
# 1  microsoft  microsoft   BE211
#
#                                            nuts_name  urban_type country  \
# 0  Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...           1      BE
# 1                                     Arr. Antwerpen           1      BE
#
#    nr_buildings   area_sqm  num_vertices
# 0         53980   82757149        461944
# 1        259775  190501850       1594980
# 2024-02-07 21:48:01.982827 total number of regions computed: 44
# ******

# %% [markdown]
# # Boundaries statistics

# %%
import geopandas as gpd
import pandas as pd
zipped_shapefile_path = '/mnt/CAS/20240101_foss4g/datasets/in/NUTS_RG_01M_2016_4326.shp.zip'
gdf_lau = gpd.read_file('zip://' + zipped_shapefile_path)
print('nr of lau3 regions per country')
gdf_lau_stat=pd.DataFrame(gdf_lau[gdf_lau['LEVL_CODE']==3].groupby(['CNTR_CODE'])['NUTS_ID'].count()).reset_index()
gdf_lau_stat.sort_values(by='NUTS_ID',ascending=False)
# Out:
# nr of lau3 regions per country
#    CNTR_CODE  NUTS_ID
# 7         DE      401
# 36        UK      179
# 18        IT      110
# 13        FR      101
# 35        TR       81
# 28        PL       73
# 11        ES       59
# 10        EL       52
# 2         BE       44
# 30        RO       42
# 26        NL       40
# 1         AT       35
# 3         BG       28
# 4         CH       26
# 31        RS       25
# 29        PT       25
# 14        HR       21
# 32        SE       21
# 15        HU       20
# 12        FI       19
# 27        NO       18
# 6         CZ       14
# 33        SI       12
# 0         AL       12
# 8         DK       11
# 20        LT       10
# 24        MK        8
# 16        IE        8
# 34        SK        8
# 22        LV        6
# 9         EE        5
# 25        MT        2
# 17        IS        2
# 23        ME        1
# 21        LU        1
# 19        LI        1
# 5         CY        1
